# %%
from pathlib import Path

from PIL import Image, ImageDraw, ImageFont

import matplotlib.pyplot as plt

import numpy as np

# %%
# 字体地址
FONT_PATHS = {
    "Longcang":       Path("fonts/longcang.ttf"),
    "Chenyu":         Path("fonts/chenyu.ttf"),
    "LXGW Wenkai":    Path("fonts/lxgw-wenkai.ttf"),
    "Iansui":         Path("fonts/iansui.ttf"),
    "LXGW Marker":    Path("fonts/lxgw-marker.ttf"),
    "Liujian":        Path("fonts/liujian.ttf"),
    "Zhimangxing":    Path("fonts/zhimangxing.ttf"),
    "Zcool Xiaowei":  Path("fonts/zcool-xiaowei.ttf"),
    "Mashan":         Path("fonts/mashan.ttf"),
    "Yozai":          Path("fonts/yozai.ttf"),
} 

OUTPUT_PATHS = {
    "Longcang":       Path("./Longcang/"),
    "Chenyu":         Path("./Chenyu/"),
    "LXGW Wenkai":    Path("./LXGW Wenkai/"),
    "Iansui":         Path("./Iansui/"),
    "LXGW Marker":    Path("./LXGW Marker/"),
    "Liujian":        Path("./Liujian/"),
    "Zhimangxing":    Path("./Zhimangxing/"),
    "Zcool Xiaowei":  Path("./Zcool Xiaowei/"),
    "Mashan":         Path("./Mashan/"),
    "Yozai":          Path("./Yozai/"),
} 

# 画布大小和字体大小
IMAGE_SIZE = 512, 512
FONT_SIZE = 400

# 小批量字体测试样例
ZI_SAMPLE_20 = "床前明月光疑是地上霜举头望明月低头思故乡"

# %%
from tools import batch_generate_images, generate_image

generate_image("李", FONT_PATHS["Longcang"], IMAGE_SIZE, FONT_SIZE)
batch_generate_images(ZI_SAMPLE_20, FONT_PATHS["Longcang"], OUTPUT_PATHS["Longcang"])
# Out:
# ([PosixPath('Longcang/5E8A.png'),
#   PosixPath('Longcang/524D.png'),
#   PosixPath('Longcang/660E.png'),
#   PosixPath('Longcang/6708.png'),
#   PosixPath('Longcang/5149.png'),
#   PosixPath('Longcang/7591.png'),
#   PosixPath('Longcang/662F.png'),
#   PosixPath('Longcang/5730.png'),
#   PosixPath('Longcang/4E0A.png'),
#   PosixPath('Longcang/971C.png'),
#   PosixPath('Longcang/4E3E.png'),
#   PosixPath('Longcang/5934.png'),
#   PosixPath('Longcang/671B.png'),
#   PosixPath('Longcang/660E.png'),
#   PosixPath('Longcang/6708.png'),
#   PosixPath('Longcang/4F4E.png'),
#   PosixPath('Longcang/5934.png'),
#   PosixPath('Longcang/601D.png'),
#   PosixPath('Longcang/6545.png'),
#   PosixPath('Longcang/4E61.png')],
#  [])
